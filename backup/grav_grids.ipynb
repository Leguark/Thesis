# %% [markdown]
# # Sandstone gravity and magnetic potential-field data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
Sst_grav_1000 = np.loadtxt('Temp_Sandstone\Sandstone_geophys\Sst_grav_1000.xyz')
Sst_grav_2000 = np.loadtxt('Temp_Sandstone\Sandstone_geophys\Sst_grav_2000.xyz')
Sst_grav_500 = np.loadtxt('Temp_Sandstone\Sandstone_geophys\Sst_grav_500.xyz')

# %%
plt.imshow(Sst_grav_1000[:,3].reshape((63,43)), origin = "lower left",
           interpolation = 'nearest', cmap = 'jet')

# %%
a = Sst_grav_1000[:,3].reshape((63,43))
len(a[0,:])
# Out:
# 43

# %%
plt.figure(figsize = (12,8))
plt.imshow(Sst_grav_500[:,3].reshape((125,85)) - np.mean(Sst_grav_500[:,3]), origin = "lower left",
           interpolation = 'nearest', cmap = 'jet')
plt.title("Bouger Gravity - reduced by mean value")
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x111aba560>

# %% [markdown]
# ## TMI Data

# %%
Sst_tmi_250 = np.loadtxt('Sst_TMI_250.xyz')

# %%
plt.figure(figsize = (12,8))
plt.imshow((Sst_tmi_250[:,3].reshape((249,169))+2500)**(1/3.), origin = "lower left",
           interpolation = 'nearest', cmap = 'jet')
plt.title("Bouger Gravity - reduced by mean value")
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11424c8c0>

# %%
np.min(Sst_tmi_250[:,3])
# Out:
# -2224.3879999999999
